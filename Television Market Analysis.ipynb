# %% [markdown]
# Exploratory Data Analysis using Altair, Matplotlib, NumPy, Pandas & Seaborn libraries for Television available in the Indian market with 7 attributes and 912 samples taken from Flipkart and answer the following questions :
#
# 1. Types of Television available in the market?
# 2. Number of Television manufactures in the market?
# 3. Types of Television availables in the market?
# 4. Types of operation systems in Television availables in the market?
# 4. What are the top 10 Television brands?
# 5. Which brand has the most Television sets on the market?
# 6. Rating (Out of 5) of the Television Brands availables in the market?
# 7. Average selling price by Brand, Resolution & Operating System of the Televisions?

# %% [markdown]
# **Importing Libraries and Datasets of Television**

# %%
import altair as alt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('C:/Users/SOUBHIK MANDAL/Desktop/jupyter notebook/Television Market Analysis/TV_Final.csv')
df
# Out:
#        Brand     Resolution  Size   Selling Price  Original Price  \
# 0    TOSHIBA   Ultra HD LED     55          37999           54990
# 1       TCL   QLED Ultra HD     55          52999          129990
# 2    realme          HD LED     32          13999           17999
# 3        Mi          HD LED     32          14999           19999
# 4    realme          HD LED     32          12999           21999
# ..       ...            ...    ...            ...             ...
# 907    SONY     Full HD LED     43          44999           57900
# 908    SONY     Full HD LED     40          41499           51900
# 909    SONY    Ultra HD LED     65         149990          184990
# 910    SONY          HD LED     32          32900           32900
# 911    SONY     Full HD LED     43          56900           56900
#
#     Operating System  Rating
# 0              VIDAA     4.3
# 1            Android     4.4
# 2            Android     4.3
# 3            Android     4.4
# ...

# %%
df.dtypes
# Out:
# Brand                object
# Resolution           object
# Size                  int64
# Selling Price         int64
# Original Price        int64
# Operating System     object
# Rating              float64
# dtype: object

# %%
df.nunique()
# Out:
# Brand                59
# Resolution            5
# Size                 27
# Selling Price       515
# Original Price      455
# Operating System      7
# Rating               25
# dtype: int64

# %%
colors = ["#0000FF","#00FF00","#FFFF00","#FF7F00","#FF0000","#4361EE"]
palette = sns.color_palette(palette = colors)

sns.palplot(palette, size =1)
plt.show()

# %% [markdown]
# **Types of Television availables in the market**

# %%
df['Brand'].groupby(df['Resolution']).count().sort_values(ascending=False)
# Out:
# Resolution
# Ultra HD LED     399
# HD LED           229
# Full HD LED      220
# QLED Ultra HD     60
# HD Plasma          4
# Name: Brand, dtype: int64

# %%
labels = 'Ultra HD LED', 'QLED Ultra HD', 'HD LED', 'Full HD LED','HD Plasma'
sizes = [399,229,220,60,4]
fig, ax = plt.subplots(figsize=(10,6))
fig.set_facecolor('white')
ax.pie(sizes, labels=labels, colors=["#0000FF","#00FF00","#FFFF00","#FF7F00","#FF0000"],autopct='%1.1f%%', startangle=60,textprops={'color':'black','weight':'bold','fontsize':12.5})
ax.axis('equal')
plt.show()

# %% [markdown]
# **Brands of Television availables in the market**

# %%
df['Brand'].nunique()
# Out:
# 59

# %%
df['Brand'].unique()
# Out:
# array(['TOSHIBA', 'TCL ', 'realme ', 'Mi ', 'OnePlus', 'Hisense', 'LG ',
#        'MarQ by Flipkart', 'iFFALCON by TCL', 'Coocaa ', 'SAMSUNG',
#        'Infinix', 'Vu', 'Nokia ', 'Thomson', 'SONY ', 'KODAK ',
#        'MOTOROLA', 'PHILIPS', 'Acer', 'Blaupunkt', 'Adsun', 'T-Series',
#        'Panasonic', 'Micromax', 'Sansui ', 'Croma ', 'Candes ', 'Dyanora',
#        'Haier ', 'Onida', 'RGL ', 'Lloyd ', 'LumX ', 'Onix ', 'IMPEX ',
#        'BPL ', 'CloudWalker', 'Oxygen ', 'Power Guard', 'Akai ', 'VG ',
#        'Sun King', 'Compaq ', 'HUIDI ', 'Intex ', 'DETEL ', 'JVC',
#        'G-TEN ', 'Skyworth', 'Maser ', 'Sanyo ', 'MURPHY ', 'Samsung',
#        'Dektron', 'Sharp ', 'KRISONS', 'Weston ', 'AISEN  '], dtype=object)

# %%
df['Brand'].groupby(df['Brand']).count().sort_values(ascending=False).iloc[:10]
# Out:
# Brand
# SAMSUNG            140
# LG                 122
# SONY                62
# TCL                 44
# Panasonic           30
# Micromax            25
# Vu                  23
# Lloyd               22
# iFFALCON by TCL     19
# Mi                  19
# Name: Brand, dtype: int64

# %%
sns.set_style('white')
plt.figure(figsize=(10,7))
sns.countplot(y="Brand", hue="Resolution", data=df, palette=colors,order=df["Brand"].value_counts().iloc[:5].index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Brand'>

# %% [markdown]
# **Rating of the Television Brands availables in the market**

# %%
round(df.groupby('Brand')['Rating'].mean().sort_values(ascending=False),1)
# Out:
# Brand
# SONY                4.5
# OnePlus             4.4
# Hisense             4.4
# Haier               4.4
# Vu                  4.4
# TOSHIBA             4.4
# MOTOROLA            4.3
# Mi                  4.3
# Compaq              4.3
# Onida               4.3
# Thomson             4.3
# Onix                4.3
# KODAK               4.3
# Dektron             4.3
# iFFALCON by TCL     4.3
# LG                  4.3
# realme              4.3
# SAMSUNG             4.3
# MarQ by Flipkart    4.3
# Nokia               4.3
# Coocaa              4.2
# Blaupunkt           4.2
# Weston              4.2
# TCL                 4.2
# Sanyo               4.2
# Infinix             4.2
# Intex               4.2
# Panasonic           4.2
# IMPEX               4.1
# Croma               4.1
# Sansui              4.1
# Micromax            4.1
# PHILIPS             4.1
# HUIDI               4.1
# CloudWalker         4.1
# Samsung             4.1
# Lloyd               4.1
# Candes              4.1
# ...

# %%
list1 = ["SONY","OnePlus","Haier","Vu","TOSHIBA","MOTOROLA","Mi","Compaq","Onida","Thomson",
        "KODAK","LG","realme","SAMSUNG","Nokia","Panasonic","Sansui","Micromax","PHILIPS","Samsung","JVC"]

list2 = ["Hisense","Thomson","Onix","KODAK","Dektron","iFFALCON by TCL","MarQ by Flipkart","Nokia","Coocaa","Blaupunkt","Weston","TCL",
        "Infinix","Sanyo","Intex","IMPEX","Croma","HUIDI","CloudWalker","Lloyd", 
        "Candes","Detel","LumX"]
series1 = df["Brand"].isin(list1)
series2 = df["Brand"].isin(list2)
df_f1= df[series1]
df_f2= df[series2]
fig, axs = plt.subplots(ncols=2,figsize=(20,5))
ax1 = sns.stripplot(x="Rating", y="Selling Price", data=df_f1,hue="Brand", palette=colors,ax=axs[0])
ax2 = sns.stripplot(x="Rating", y="Selling Price", data=df_f2,hue="Brand", palette=colors,ax=axs[1])

# %% [markdown]
# **Average selling price by Brand,Resolution & Operating system**

# %%
df.groupby('Brand')['Selling Price'].mean().sort_values(ascending=False).apply(np.ceil)
# Out:
# Brand
# Sharp               149672.0
# Samsung             121630.0
# SAMSUNG             106410.0
# LG                   96915.0
# Hisense              89796.0
# SONY                 89343.0
# TCL                  55799.0
# iFFALCON by TCL      54235.0
# Panasonic            53494.0
# Akai                 52003.0
# OnePlus              47376.0
# Vu                   46650.0
# Compaq               45999.0
# Sanyo                45499.0
# Weston               43390.0
# Oxygen               40327.0
# Nokia                38863.0
# TOSHIBA              38853.0
# MOTOROLA             38399.0
# Sansui               37672.0
# Haier                36617.0
# AISEN                35463.0
# BPL                  34618.0
# Onix                 34217.0
# Lloyd                34162.0
# PHILIPS              34114.0
# JVC                  32497.0
# CloudWalker          32332.0
# Acer                 31665.0
# Mi                   30788.0
# Power Guard          30510.0
# Onida                29708.0
# ...

# %%
alt.Chart(df).mark_point(filled=True,size=40).encode(
    x='Original Price',
    y='Selling Price',
    color='Brand',
    tooltip=['Brand', 'Selling Price', 'Original Price']
).interactive()
# Out:
# alt.Chart(...)

# %%
df['Resolution'].unique()
# Out:
# array(['Ultra HD LED', 'QLED Ultra HD', 'HD LED', 'Full HD LED',
#        'HD Plasma'], dtype=object)

# %%
sns.barplot(x=df['Resolution'], y=df['Selling Price'],palette=colors)
plt.xticks(rotation="vertical")
plt.show()

# %%
df['Operating System'].unique()
# Out:
# array(['VIDAA', 'Android', 'Linux', nan, 'Tizen', 'WebOS', 'HomeOS',
#        'FireTV OS'], dtype=object)

# %%
sns.barplot(x=df['Operating System'], y=df['Selling Price'],palette=colors)
plt.xticks(rotation="vertical")
plt.show()

# %%
sns.barplot(x=df['Brand'], y=df['Selling Price'],palette=colors)
plt.xticks(rotation="vertical")
plt.show()
